# %% [markdown]
# # Gradiente Descendente

# %%
import numpy as np

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100, 1))

# %%
learning_rate = 0.1
n_iterations = 1000
m = 100 # numero de samples

theta = np.random.randn(2,1)

# %%
X_b = np.c_[np.ones((100, 1)), X] # inclue o termo bias

for iteration in range(n_iterations):
    gradients = (2/m) * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients

# %%
theta
# Out:
# array([[3.93617545],
#        [3.06515841]])

# %% [markdown]
# ## Gradiente Descendente Estocástico

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(max_iter=5000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(X, y.ravel())
# Out:
# SGDRegressor(eta0=0.1, max_iter=5000, penalty=None)

# %%
sgd_reg.intercept_, sgd_reg.coef_ # x e y
# Out:
# (array([3.86238412]), array([3.00589256]))

# %% [markdown]
# ![image.png](attachment:image.png)
